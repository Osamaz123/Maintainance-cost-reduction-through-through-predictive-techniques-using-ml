# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport
from scipy.stats import boxcox
from sklearn.preprocessing import StandardScaler

# %%
# Load the dataset
data = pd.read_csv("predictive_maintenance.csv")

# %% [markdown]
# ### Data Exploration and Insights

# %%
# Display the first few rows
data.head(10)
# Out:
#      date    device  failure    metric1  metric2  metric3  metric4  metric5  \
# 0  1/1/15  S1F01085        0  215630672       56        0       52        6
# 1  1/1/15  S1F0166B        0   61370680        0        3        0        6
# 2  1/1/15  S1F01E6Y        0  173295968        0        0        0       12
# 3  1/1/15  S1F01JE0        0   79694024        0        0        0        6
# 4  1/1/15  S1F01R2B        0  135970480        0        0        0       15
# 5  1/1/15  S1F01TD5        0   68837488        0        0       41        6
# 6  1/1/15  S1F01XDJ        0  227721632        0        0        0        8
# 7  1/1/15  S1F023H2        0  141503600        0        0        1       19
# 8  1/1/15  S1F02A0J        0    8217840        0        1        0       14
# 9  1/1/15  S1F02DZ2        0  116440096        0      323        9        9
#
#    metric6  metric7  metric8  metric9
# 0   407438        0        0        7
# 1   403174        0        0        0
# 2   237394        0        0        0
# 3   410186        0        0        0
# 4   313173        0        0        3
# 5   413535        0        0        1
# 6   402525        0        0        0
# 7   494462       16       16        3
# 8   311869        0        0        0
# 9   407905        0        0      164

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124494 entries, 0 to 124493
# Data columns (total 12 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   date     124494 non-null  object
#  1   device   124494 non-null  object
#  2   failure  124494 non-null  int64
#  3   metric1  124494 non-null  int64
#  4   metric2  124494 non-null  int64
#  5   metric3  124494 non-null  int64
#  6   metric4  124494 non-null  int64
#  7   metric5  124494 non-null  int64
#  8   metric6  124494 non-null  int64
#  9   metric7  124494 non-null  int64
#  10  metric8  124494 non-null  int64
#  11  metric9  124494 non-null  int64
# dtypes: int64(10), object(2)
# memory usage: 11.4+ MB

# %%
data.count()
# Out:
# date       124494
# device     124494
# failure    124494
# metric1    124494
# metric2    124494
# metric3    124494
# metric4    124494
# metric5    124494
# metric6    124494
# metric7    124494
# metric8    124494
# metric9    124494
# dtype: int64

# %%
data.nunique()
# Out:
# date          304
# device       1169
# failure         2
# metric1    123877
# metric2       558
# metric3        47
# metric4       115
# metric5        60
# metric6     44838
# metric7        28
# metric8        28
# metric9        65
# dtype: int64

# %%
data.isnull().sum()
# Out:
# date       0
# device     0
# failure    0
# metric1    0
# metric2    0
# metric3    0
# metric4    0
# metric5    0
# metric6    0
# metric7    0
# metric8    0
# metric9    0
# dtype: int64

# %%
failure_counts = data["failure"].value_counts()
failure_percentages = failure_counts / len(data) * 100

# Print the results
print("Failure Counts:")
print(failure_counts)
print("\nFailure Percentages:")
print(failure_percentages)
# Out:
# Failure Counts:
# 0    124388
# 1       106
# Name: failure, dtype: int64
#
# Failure Percentages:
# 0    99.914855
# 1     0.085145
# Name: failure, dtype: float64

# %%
# Filter the dataset for rows where failure = 1
failed_devices = data[data['failure'] == 1]

# Get the total number of unique devices that experienced failure
total_unique_failed_devices = failed_devices['device'].nunique()

print("Total unique failure devices:", total_unique_failed_devices)
# Out:
# Total unique failure devices: 106

# %%
# Generate summary statistics for numerical features
print(data.describe())
# Out:
#              failure       metric1        metric2        metric3  \
# count  124494.000000  1.244940e+05  124494.000000  124494.000000
# mean        0.000851  1.223881e+08     159.484762       9.940455
# std         0.029167  7.045933e+07    2179.657730     185.747321
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%         0.000000  6.128476e+07       0.000000       0.000000
# 50%         0.000000  1.227974e+08       0.000000       0.000000
# 75%         0.000000  1.833096e+08       0.000000       0.000000
# max         1.000000  2.441405e+08   64968.000000   24929.000000
#
#              metric4        metric5        metric6        metric7  \
# count  124494.000000  124494.000000  124494.000000  124494.000000
# mean        1.741120      14.222669  260172.657726       0.292528
# std        22.908507      15.943028   99151.078547       7.436924
# min         0.000000       1.000000       8.000000       0.000000
# 25%         0.000000       8.000000  221452.000000       0.000000
# 50%         0.000000      10.000000  249799.500000       0.000000
# 75%         0.000000      12.000000  310266.000000       0.000000
# max      1666.000000      98.000000  689161.000000     832.000000
#
#              metric8        metric9
# count  124494.000000  124494.000000
# mean        0.292528      12.451524
# std         7.436924     191.425623
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         0.000000       0.000000
# max       832.000000   18701.000000

# %% [markdown]
# The count for metric1 is the same as for the other metrics (124494), but it’s displayed in scientific notation (1.244940e+05) because of the large mean value that follows it in the table.

# %%
# Identify all duplicates (including the first occurrence)
duplicates = data.duplicated()

# Count the number of duplicates (excluding the first occurrence)
num_duplicates = duplicates.sum() - duplicates.head(1).sum()

print(f"Number of duplicate rows (excluding first occurrence): {num_duplicates}")
# Out:
# Number of duplicate rows (excluding first occurrence): 1

# %%
 
profile = ProfileReport(data, minimal=False)

# Generate and save the HTML report
profile.to_file("profile_report_full.html")
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Insights
#
#
# - The dataset consists of **124,494** entries and **12** columns.
# - Columns include 'date', 'device', 'failure', and numerical metrics from 'metric1' to 'metric9'.
# - The data is clean there are **no missing values** since the count of non-null values for each column matches the total number of entries (124,494).
# - 'date' and 'device' columns are of object data type, while other columns are of integer data type.
# - It is **imbalanced data set**, as the failuer class is about **0.1%** of unfailure class. Here oversampling approach is used to deal with imbalanced dataset.
#
# - **'date'** column has **304** unique values, indicating that the dataset spans over multiple days.
# - There are total **1,169**  unique devices out of which total unique failure devices: **106**.
# - Numerical metrics have varying numbers of unique values, suggesting differences in data distribution and variability across metrics.
# - **metric7** and **metric8** seems to **exactly same**, so we can drop one of them
# - metric 2,3,4,7,9 are **highly skewed.**

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# - date exploration and visualization
# - device come back to use
# - Create feature called 'failure_before'

# %%
print("Start Date:", data['date'].min())
print("End Date:", data['date'].max())
# Out:
# Start Date: 1/1/15
# End Date: 9/9/15

# %%
# 2. Convert data types
# Convert 'date' column to datetime data type
data['date'] = pd.to_datetime(data['date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124494 entries, 0 to 124493
# Data columns (total 12 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   date     124494 non-null  datetime64[ns]
#  1   device   124494 non-null  object
#  2   failure  124494 non-null  int64
#  3   metric1  124494 non-null  int64
#  4   metric2  124494 non-null  int64
#  5   metric3  124494 non-null  int64
#  6   metric4  124494 non-null  int64
#  7   metric5  124494 non-null  int64
#  8   metric6  124494 non-null  int64
#  9   metric7  124494 non-null  int64
#  10  metric8  124494 non-null  int64
#  11  metric9  124494 non-null  int64
# dtypes: datetime64[ns](1), int64(10), object(1)
# memory usage: 11.4+ MB

# %%
data['month'] = data['date'].dt.month

# %%
data['weekday'] = data['date'].dt.dayofweek
data
# Out:
#              date    device  failure    metric1  metric2  metric3  metric4  \
# 0      2015-01-01  S1F01085        0  215630672       56        0       52
# 1      2015-01-01  S1F0166B        0   61370680        0        3        0
# 2      2015-01-01  S1F01E6Y        0  173295968        0        0        0
# 3      2015-01-01  S1F01JE0        0   79694024        0        0        0
# 4      2015-01-01  S1F01R2B        0  135970480        0        0        0
# ...           ...       ...      ...        ...      ...      ...      ...
# 124489 2015-11-02  Z1F0MA1S        0   18310224        0        0        0
# 124490 2015-11-02  Z1F0Q8RT        0  172556680       96      107        4
# 124491 2015-11-02  Z1F0QK05        0   19029120     4832        0        0
# 124492 2015-11-02  Z1F0QL3N        0  226953408        0        0        0
# 124493 2015-11-02  Z1F0QLC1        0   17572840        0        0        0
#
#         metric5  metric6  metric7  metric8  metric9  month  weekday
# 0             6   407438        0        0        7      1        3
# 1             6   403174        0        0        0      1        3
# 2            12   237394        0        0        0      1        3
# 3             6   410186        0        0        0      1        3
# 4            15   313173        0        0        3      1        3
# ...         ...      ...      ...      ...      ...    ...      ...
# 124489       10   353705        8        8        0     11        0
# 124490       11   332792        0        0       13     11        0
# 124491       11   350410        0        0        0     11        0
# 124492       12   358980        0        0        0     11        0
# 124493       10   351431        0        0        0     11        0
#
# [124494 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124494 entries, 0 to 124493
# Data columns (total 14 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   date     124494 non-null  datetime64[ns]
#  1   device   124494 non-null  object
#  2   failure  124494 non-null  int64
#  3   metric1  124494 non-null  int64
#  4   metric2  124494 non-null  int64
#  5   metric3  124494 non-null  int64
#  6   metric4  124494 non-null  int64
#  7   metric5  124494 non-null  int64
#  8   metric6  124494 non-null  int64
#  9   metric7  124494 non-null  int64
#  10  metric8  124494 non-null  int64
#  11  metric9  124494 non-null  int64
#  12  month    124494 non-null  int64
#  13  weekday  124494 non-null  int64
# dtypes: datetime64[ns](1), int64(12), object(1)
# memory usage: 13.3+ MB

# %%
data
# Out:
#              date    device  failure    metric1  metric2  metric3  metric4  \
# 0      2015-01-01  S1F01085        0  215630672       56        0       52
# 1      2015-01-01  S1F0166B        0   61370680        0        3        0
# 2      2015-01-01  S1F01E6Y        0  173295968        0        0        0
# 3      2015-01-01  S1F01JE0        0   79694024        0        0        0
# 4      2015-01-01  S1F01R2B        0  135970480        0        0        0
# ...           ...       ...      ...        ...      ...      ...      ...
# 124489 2015-11-02  Z1F0MA1S        0   18310224        0        0        0
# 124490 2015-11-02  Z1F0Q8RT        0  172556680       96      107        4
# 124491 2015-11-02  Z1F0QK05        0   19029120     4832        0        0
# 124492 2015-11-02  Z1F0QL3N        0  226953408        0        0        0
# 124493 2015-11-02  Z1F0QLC1        0   17572840        0        0        0
#
#         metric5  metric6  metric7  metric8  metric9  month  weekday
# 0             6   407438        0        0        7      1        3
# 1             6   403174        0        0        0      1        3
# 2            12   237394        0        0        0      1        3
# 3             6   410186        0        0        0      1        3
# 4            15   313173        0        0        3      1        3
# ...         ...      ...      ...      ...      ...    ...      ...
# 124489       10   353705        8        8        0     11        0
# 124490       11   332792        0        0       13     11        0
# 124491       11   350410        0        0        0     11        0
# 124492       12   358980        0        0        0     11        0
# 124493       10   351431        0        0        0     11        0
#
# [124494 rows x 14 columns]

# %%
data.nunique()
# Out:
# date          304
# device       1169
# failure         2
# metric1    123877
# metric2       558
# metric3        47
# metric4       115
# metric5        60
# metric6     44838
# metric7        28
# metric8        28
# metric9        65
# month          11
# weekday         7
# dtype: int64

# %%
data['month'].value_counts()
# Out:
# 1     25032
# 3     19833
# 2     19500
# 4     12012
# 5     11330
# 7     10531
# 6     10469
# 8      8346
# 9      4470
# 10     2940
# 11       31
# Name: month, dtype: int64

# %%
data.groupby('month').agg({'device':lambda x: x.nunique()})
# Out:
#        device
# month
# 1        1164
# 2         726
# 3         685
# 4         491
# 5         424
# 6         353
# 7         346
# 8         334
# 9         184
# 10        146
# 11         31

# %%
data.groupby('month').agg({'device':lambda x: x.nunique()}).plot()
# Out:
# <Axes: xlabel='month'>

# %%
data.groupby(data['date'].dt.month)['failure'].value_counts().unstack(fill_value=0)
# Out:
# failure      0   1
# date
# 1        25008  24
# 2        19486  14
# 3        19824   9
# 4        12003   9
# 5        11309  21
# 6        10463   6
# 7        10515  16
# 8         8342   4
# 9         4470   0
# 10        2937   3
# 11          31   0

# %%
# failure_counts_by_weekday
data.groupby('weekday')['failure'].value_counts().unstack(fill_value=0)
# Out:
# failure      0   1
# weekday
# 0        17859  27
# 1        17516  18
# 2        17121  15
# 3        18119  22
# 4        18029  12
# 5        17889   8
# 6        17855   4

# %%
# max_date_per_device = 
data.groupby('device')['date'].max()

# print("Maximum date for each device:")
# print(max_date_per_device)
# Out:
# device
# S1F01085   2015-01-06
# S1F013BB   2015-05-11
# S1F0166B   2015-01-06
# S1F01E6Y   2015-02-17
# S1F01JE0   2015-01-06
#               ...
# Z1F1VMZB   2015-10-19
# Z1F1VQFY   2015-06-30
# Z1F26YZB   2015-03-25
# Z1F282ZV   2015-03-25
# Z1F2PBHX   2015-04-06
# Name: date, Length: 1169, dtype: datetime64[ns]

# %%
data['max_date_per_device'] = data.groupby('device')['date'].transform('max')

# %%
data
# Out:
#              date    device  failure    metric1  metric2  metric3  metric4  \
# 0      2015-01-01  S1F01085        0  215630672       56        0       52
# 1      2015-01-01  S1F0166B        0   61370680        0        3        0
# 2      2015-01-01  S1F01E6Y        0  173295968        0        0        0
# 3      2015-01-01  S1F01JE0        0   79694024        0        0        0
# 4      2015-01-01  S1F01R2B        0  135970480        0        0        0
# ...           ...       ...      ...        ...      ...      ...      ...
# 124489 2015-11-02  Z1F0MA1S        0   18310224        0        0        0
# 124490 2015-11-02  Z1F0Q8RT        0  172556680       96      107        4
# 124491 2015-11-02  Z1F0QK05        0   19029120     4832        0        0
# 124492 2015-11-02  Z1F0QL3N        0  226953408        0        0        0
# 124493 2015-11-02  Z1F0QLC1        0   17572840        0        0        0
#
#         metric5  metric6  metric7  metric8  metric9  month  weekday  \
# 0             6   407438        0        0        7      1        3
# 1             6   403174        0        0        0      1        3
# 2            12   237394        0        0        0      1        3
# 3             6   410186        0        0        0      1        3
# 4            15   313173        0        0        3      1        3
# ...         ...      ...      ...      ...      ...    ...      ...
# 124489       10   353705        8        8        0     11        0
# 124490       11   332792        0        0       13     11        0
# 124491       11   350410        0        0        0     11        0
# 124492       12   358980        0        0        0     11        0
# 124493       10   351431        0        0        0     11        0
#
#        max_date_per_device
# 0               2015-01-06
# 1               2015-01-06
# 2               2015-02-17
# 3               2015-01-06
# 4               2015-08-24
# ...                    ...
# 124489          2015-11-02
# 124490          2015-11-02
# 124491          2015-11-02
# 124492          2015-11-02
# 124493          2015-11-02
#
# [124494 rows x 15 columns]

# %%
data.count()
# Out:
# date                   124494
# device                 124494
# failure                124494
# metric1                124494
# metric2                124494
# metric3                124494
# metric4                124494
# metric5                124494
# metric6                124494
# metric7                124494
# metric8                124494
# metric9                124494
# month                  124494
# weekday                124494
# max_date_per_device    124494
# dtype: int64

# %% [markdown]
# dff=df[(df.failure==1)&(df.date!=df.max_date)]
#
# dff
#
# Max date means the last day the device got checked. If the max day is ahead of failure date, it means this device returned to use after failed because got fixed.

# %% [markdown]
#  ### last recorded date of telemetry for each device

# %%
latest_dates = data.groupby('device')['date'].transform(max)
df1 = data[data['date'] == latest_dates]

# %%
df1.shape
# Out:
# (1169, 15)

# %%
df1
# Out:
#              date    device  failure    metric1  metric2  metric3  metric4  \
# 3051   2015-01-03  W1F0WJFT        0  142903640        0        0        0
# 3516   2015-01-04  S1F04KSC        0  243217648      392    24929      529
# 4673   2015-01-05  S1F03RV3        0   13723560        0        0        0
# 4685   2015-01-05  S1F05NAJ        0  201934440      392        0        0
# 4686   2015-01-05  S1F05P51        0   12164440      512        0        0
# ...           ...       ...      ...        ...      ...      ...      ...
# 124489 2015-11-02  Z1F0MA1S        0   18310224        0        0        0
# 124490 2015-11-02  Z1F0Q8RT        0  172556680       96      107        4
# 124491 2015-11-02  Z1F0QK05        0   19029120     4832        0        0
# 124492 2015-11-02  Z1F0QL3N        0  226953408        0        0        0
# 124493 2015-11-02  Z1F0QLC1        0   17572840        0        0        0
#
#         metric5  metric6  metric7  metric8  metric9  month  weekday  \
# 3051          9   217819        0        0        1      1        5
# 3516          3   339302        0        0    10137      1        6
# 4673          8   263330        0        0        0      1        0
# 4685          4   341352        0        0        1      1        0
# 4686          5   335898        0        0        0      1        0
# ...         ...      ...      ...      ...      ...    ...      ...
# 124489       10   353705        8        8        0     11        0
# 124490       11   332792        0        0       13     11        0
# 124491       11   350410        0        0        0     11        0
# 124492       12   358980        0        0        0     11        0
# 124493       10   351431        0        0        0     11        0
#
#        max_date_per_device
# 3051            2015-01-03
# 3516            2015-01-04
# 4673            2015-01-05
# 4685            2015-01-05
# 4686            2015-01-05
# ...                    ...
# 124489          2015-11-02
# 124490          2015-11-02
# 124491          2015-11-02
# 124492          2015-11-02
# 124493          2015-11-02
#
# [1169 rows x 15 columns]

# %% [markdown]
# #### Create feature called 'failure_before'

# %% [markdown]
# If we just take the last record for the devices, we may lose information from those come back after failed ones

# %%
potential_fixed_devices = data[(data['failure'] == 1) & (data['date'] != data['max_date_per_device'])]
potential_fixed_devices
# Out:
#              date    device  failure    metric1  metric2  metric3  metric4  \
# 77958  2015-05-05  S1F136J0        1  131519808        0        0       25
# 79590  2015-05-09  W1F0KCP2        1  176861128    10392        0      121
# 79601  2015-05-09  W1F0M35B        1  141805096        0        0        1
# 101999 2015-07-12  S1F0GPFZ        1  236544080        0        0        0
# 104223 2015-07-18  W1F11ZG9        1   32671632      368        9      486
#
#         metric5  metric6  metric7  metric8  metric9  month  weekday  \
# 77958        16   343464        8        8        0      5        1
# 79590         6   310699        0        0        0      5        5
# 79601         7   267203        0        0        0      5        5
# 101999        9   264594        0        0        0      7        6
# 104223        3   344433        0        0        1      7        5
#
#        max_date_per_device
# 77958           2015-05-06
# 79590           2015-05-11
# 79601           2015-05-11
# 101999          2015-07-24
# 104223          2015-08-17

# %%
df1.loc[:, 'failure_before'] = 0
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16020\3585799663.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[:, 'failure_before'] = 0

# %%
df1.loc[df1.device == 'S1F136J0','failure_before'] = 1
df1.loc[df1.device == 'W1F0KCP2','failure_before'] = 1
df1.loc[df1.device == 'W1F0M35B','failure_before'] = 1
df1.loc[df1.device == 'S1F0GPFZ','failure_before'] = 1
df1.loc[df1.device == 'W1F11ZG9','failure_before'] = 1

# %%
df1.head(10)
# Out:
#            date    device  failure    metric1  metric2  metric3  metric4  \
# 3051 2015-01-03  W1F0WJFT        0  142903640        0        0        0
# 3516 2015-01-04  S1F04KSC        0  243217648      392    24929      529
# 4673 2015-01-05  S1F03RV3        0   13723560        0        0        0
# 4685 2015-01-05  S1F05NAJ        0  201934440      392        0        0
# 4686 2015-01-05  S1F05P51        0   12164440      512        0        0
# 4687 2015-01-05  S1F05P5Z        0   56574384      936        0        3
# 4692 2015-01-05  S1F08R94        0   16377144        0        1        0
# 4693 2015-01-05  S1F08S38        0  120628960      760        3        2
# 4695 2015-01-05  S1F09MAK        0   97346208     8392        0        7
# 4696 2015-01-05  S1F09MSM        0  234536728      360        0        0
#
#       metric5  metric6  metric7  metric8  metric9  month  weekday  \
# 3051        9   217819        0        0        1      1        5
# 3516        3   339302        0        0    10137      1        6
# 4673        8   263330        0        0        0      1        0
# 4685        4   341352        0        0        1      1        0
# 4686        5   335898        0        0        0      1        0
# 4687        4   335893        0        0        0      1        0
# 4692        4   330296        0        0        0      1        0
# 4693        4   338658        0        0        6      1        0
# 4695        3   306534        0        0        4      1        0
# 4696        3   343127        0        0        2      1        0
#
#      max_date_per_device  failure_before
# 3051          2015-01-03               0
# 3516          2015-01-04               0
# 4673          2015-01-05               0
# 4685          2015-01-05               0
# 4686          2015-01-05               0
# 4687          2015-01-05               0
# 4692          2015-01-05               0
# 4693          2015-01-05               0
# 4695          2015-01-05               0
# 4696          2015-01-05               0

# %% [markdown]
# ## data transformation

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1169 entries, 3051 to 124493
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 1169 non-null   datetime64[ns]
#  1   device               1169 non-null   object
#  2   failure              1169 non-null   int64
#  3   metric1              1169 non-null   int64
#  4   metric2              1169 non-null   int64
#  5   metric3              1169 non-null   int64
#  6   metric4              1169 non-null   int64
#  7   metric5              1169 non-null   int64
#  8   metric6              1169 non-null   int64
#  9   metric7              1169 non-null   int64
#  10  metric8              1169 non-null   int64
#  11  metric9              1169 non-null   int64
#  12  month                1169 non-null   int64
#  13  weekday              1169 non-null   int64
#  14  max_date_per_device  1169 non-null   datetime64[ns]
#  15  failure_before       1169 non-null   int64
# dtypes: datetime64[ns](2), int64(13), object(1)
# memory usage: 155.3+ KB

# %%
print(df1.describe())
# Out:
#            failure       metric1       metric2       metric3      metric4  \
# count  1169.000000  1.169000e+03   1169.000000   1169.000000  1169.000000
# mean      0.086399  1.221612e+08    872.260051     31.243798     9.808383
# std       0.281072  7.040220e+07   5990.879345    738.252029    78.946049
# min       0.000000  0.000000e+00      0.000000      0.000000     0.000000
# 25%       0.000000  5.972926e+07      0.000000      0.000000     0.000000
# 50%       0.000000  1.222921e+08      0.000000      0.000000     0.000000
# 75%       0.000000  1.826172e+08      0.000000      0.000000     0.000000
# max       1.000000  2.433294e+08  64792.000000  24929.000000  1666.000000
#
#            metric5        metric6      metric7      metric8       metric9  \
# count  1169.000000    1169.000000  1169.000000  1169.000000   1169.000000
# mean     12.444825  269958.996578     4.443114     4.443114     49.230967
# std      12.366156  104615.250090    43.725859    43.725859    678.117966
# min       1.000000      12.000000     0.000000     0.000000      0.000000
# 25%       7.000000  212306.000000     0.000000     0.000000      0.000000
# 50%       9.000000  261020.000000     0.000000     0.000000      0.000000
# 75%      12.000000  328098.000000     0.000000     0.000000      1.000000
# max      98.000000  689161.000000   832.000000   832.000000  18701.000000
#
#              month      weekday  failure_before
# count  1169.000000  1169.000000     1169.000000
# mean      4.303678     1.522669        0.004277
# std       3.348379     1.429762        0.065288
# min       1.000000     0.000000        0.000000
# 25%       1.000000     0.000000        0.000000
# 50%       3.000000     1.000000        0.000000
# 75%       8.000000     3.000000        0.000000
# max      11.000000     6.000000        1.000000

# %%
failure_counts = data["failure"].value_counts()
failure_percentages = failure_counts / len(data) * 100

# Print the results
print("Failure Counts:")
print(failure_counts)
print("\nFailure Percentages:")
print(failure_percentages)
# Out:
# Failure Counts:
# 0    124388
# 1       106
# Name: failure, dtype: int64
#
# Failure Percentages:
# 0    99.914855
# 1     0.085145
# Name: failure, dtype: float64

# %%
df1.device
# Out:
# 3051      W1F0WJFT
# 3516      S1F04KSC
# 4673      S1F03RV3
# 4685      S1F05NAJ
# 4686      S1F05P51
#             ...
# 124489    Z1F0MA1S
# 124490    Z1F0Q8RT
# 124491    Z1F0QK05
# 124492    Z1F0QL3N
# 124493    Z1F0QLC1
# Name: device, Length: 1169, dtype: object

# %%
Id = df1.device.values.tolist()

# %%
#change device id values to the first four characters
Id1 = [] 
for i in Id:
    i = i[:4]
    Id1.append(i)

df1.device=Id1

df1.device.value_counts()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16020\1929735899.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.device=Id1
# S1F0    391
# W1F0    282
# Z1F0    149
# S1F1    139
# W1F1    138
# Z1F1     67
# Z1F2      3
# Name: device, dtype: int64

# %%
dev=pd.crosstab(df1['device'],df1['failure'])

# %%
# Create the plot
dev.plot(kind="bar", stacked=True)

# Customize the plot (optional)
plt.xlabel('Device Category')
plt.ylabel('Normalized Failure Count (0-1)')
plt.title('Normalized Failure Counts per Device Category')
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.legend(title='Failure')  # Add legend with title 'Failure'

# Show the plot
plt.show()

# %%
df1.nunique()
# Out:
# date                    104
# device                    7
# failure                   2
# metric1                1168
# metric2                 118
# metric3                  44
# metric4                  67
# metric5                  58
# metric6                1135
# metric7                  22
# metric8                  22
# metric9                  63
# month                    11
# weekday                   7
# max_date_per_device     104
# failure_before            2
# dtype: int64

# %% [markdown]
# - droping unimportant and redundant data
# - data transformation
# - standardisation

# %% [markdown]
# as we have seen earlier that metrics7 and metric8 is highly correlated so we have to drop one of them

# %%
(df1['metric7']==df1['metric8']).value_counts()
# Out:
# True    1169
# dtype: int64

# %%
df1.drop('metric8',axis=1,inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16020\4075252717.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('metric8',axis=1,inplace=True)

# %%
df1.drop(['date','max_date_per_device'],axis=1,inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16020\2044004741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(['date','max_date_per_device'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#      device  failure    metric1  metric2  metric3  metric4  metric5  metric6  \
# 3051   W1F0        0  142903640        0        0        0        9   217819
# 3516   S1F0        0  243217648      392    24929      529        3   339302
# 4673   S1F0        0   13723560        0        0        0        8   263330
# 4685   S1F0        0  201934440      392        0        0        4   341352
# 4686   S1F0        0   12164440      512        0        0        5   335898
#
#       metric7  metric9  month  weekday  failure_before
# 3051        0        1      1        5               0
# 3516        0    10137      1        6               0
# 4673        0        0      1        0               0
# 4685        0        1      1        0               0
# 4686        0        0      1        0               0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1169 entries, 3051 to 124493
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   device          1169 non-null   object
#  1   failure         1169 non-null   int64
#  2   metric1         1169 non-null   int64
#  3   metric2         1169 non-null   int64
#  4   metric3         1169 non-null   int64
#  5   metric4         1169 non-null   int64
#  6   metric5         1169 non-null   int64
#  7   metric6         1169 non-null   int64
#  8   metric7         1169 non-null   int64
#  9   metric9         1169 non-null   int64
#  10  month           1169 non-null   int64
#  11  weekday         1169 non-null   int64
#  12  failure_before  1169 non-null   int64
# dtypes: int64(12), object(1)
# memory usage: 127.9+ KB

# %%
for col in ['month','weekday']:
    df1[col]=df1[col].astype('object')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16020\1763066389.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col]=df1[col].astype('object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1169 entries, 3051 to 124493
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   device          1169 non-null   object
#  1   failure         1169 non-null   int64
#  2   metric1         1169 non-null   int64
#  3   metric2         1169 non-null   int64
#  4   metric3         1169 non-null   int64
#  5   metric4         1169 non-null   int64
#  6   metric5         1169 non-null   int64
#  7   metric6         1169 non-null   int64
#  8   metric7         1169 non-null   int64
#  9   metric9         1169 non-null   int64
#  10  month           1169 non-null   object
#  11  weekday         1169 non-null   object
#  12  failure_before  1169 non-null   int64
# dtypes: int64(10), object(3)
# memory usage: 127.9+ KB

# %% [markdown]
# ### metric 2, 3, 4, 7,9 are highly skwed so we need to handle thses

# %%
df1['metric3'].skew()
# Out:
# 32.966991669102384

# %%
# Visualize the distribution of metric2 before and after Box-Cox transformation
f, axarr = plt.subplots(1, 2, figsize=(12, 6))

# Before transformation
sns.histplot(df1['metric2'], kde=True, ax=axarr[0])
axarr[0].set_title('Skewed Distribution of metric2')

# Apply Box-Cox transformation
transformed_metric2, _ = boxcox(df1['metric2'] + 1)  # Adding 1 to handle zero values
sns.histplot(transformed_metric2, kde=True, ax=axarr[1])
axarr[1].set_title('Box-Cox Transformed Distribution of metric2')

plt.show()

# %%
# Visualize the distribution of metric2 before and after Box-Cox transformation
f, axarr = plt.subplots(1, 2, figsize=(12, 6))

# Before transformation
sns.histplot(df1['metric3'], kde=True, ax=axarr[0])
axarr[0].set_title('Skewed Distribution of metric3')

# Apply Box-Cox transformation
transformed_metric2, _ = boxcox(df1['metric3'] + 1)  # Adding 1 to handle zero values
sns.histplot(transformed_metric2, kde=True, ax=axarr[1])
axarr[1].set_title('Box-Cox Transformed Distribution of metric3')

plt.show()

# %%
# Visualize the distribution of metric2 before and after Box-Cox transformation
f, axarr = plt.subplots(1, 2, figsize=(12, 6))

# Before transformation
sns.histplot(df1['metric4'], kde=True, ax=axarr[0])
axarr[0].set_title('Skewed Distribution of metric4')

# Apply Box-Cox transformation
transformed_metric2, _ = boxcox(df1['metric4'] + 1)  # Adding 1 to handle zero values
sns.histplot(transformed_metric2, kde=True, ax=axarr[1])
axarr[1].set_title('Box-Cox Transformed Distribution of metric4')

plt.show()

# %%
# Visualize the distribution of metric2 before and after Box-Cox transformation
f, axarr = plt.subplots(1, 2, figsize=(12, 6))

# Before transformation
sns.histplot(df1['metric7'], kde=True, ax=axarr[0])
axarr[0].set_title('Skewed Distribution of metric7')

# Apply Box-Cox transformation
transformed_metric2, _ = boxcox(df1['metric7'] + 1)  # Adding 1 to handle zero values
sns.histplot(transformed_metric2, kde=True, ax=axarr[1])
axarr[1].set_title('Box-Cox Transformed Distribution of metric7')

plt.show()

# %%
# Visualize the distribution of metric2 before and after Box-Cox transformation
f, axarr = plt.subplots(1, 2, figsize=(12, 6))

# Before transformation
sns.histplot(df1['metric9'], kde=True, ax=axarr[0])
axarr[0].set_title('Skewed Distribution of metric9')

# Apply Box-Cox transformation
transformed_metric2, _ = boxcox(df1['metric9'] + 1)  # Adding 1 to handle zero values
sns.histplot(transformed_metric2, kde=True, ax=axarr[1])
axarr[1].set_title('Box-Cox Transformed Distribution of metric9')

plt.show()

# %%
print(df1.describe())
# Out:
#            failure       metric1       metric2       metric3      metric4  \
# count  1169.000000  1.169000e+03   1169.000000   1169.000000  1169.000000
# mean      0.086399  1.221612e+08    872.260051     31.243798     9.808383
# std       0.281072  7.040220e+07   5990.879345    738.252029    78.946049
# min       0.000000  0.000000e+00      0.000000      0.000000     0.000000
# 25%       0.000000  5.972926e+07      0.000000      0.000000     0.000000
# 50%       0.000000  1.222921e+08      0.000000      0.000000     0.000000
# 75%       0.000000  1.826172e+08      0.000000      0.000000     0.000000
# max       1.000000  2.433294e+08  64792.000000  24929.000000  1666.000000
#
#            metric5        metric6      metric7       metric9  failure_before
# count  1169.000000    1169.000000  1169.000000   1169.000000     1169.000000
# mean     12.444825  269958.996578     4.443114     49.230967        0.004277
# std      12.366156  104615.250090    43.725859    678.117966        0.065288
# min       1.000000      12.000000     0.000000      0.000000        0.000000
# 25%       7.000000  212306.000000     0.000000      0.000000        0.000000
# 50%       9.000000  261020.000000     0.000000      0.000000        0.000000
# 75%      12.000000  328098.000000     0.000000      1.000000        0.000000
# max      98.000000  689161.000000   832.000000  18701.000000        1.000000

# %%
# Select the numerical features for scaling
numerical_features = ['metric1', 'metric2', 'metric3', 'metric6']

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the numerical features and transform them
df_scaled = df1.copy()  # Make a copy of the original DataFrame
df_scaled[numerical_features] = scaler.fit_transform(df1[numerical_features])

# %%
df_scaled
# Out:
#        device  failure   metric1   metric2    metric3  metric4  metric5  \
# 3051     W1F0        0  0.294754 -0.145660  -0.042339        0        9
# 3516     S1F0        0  1.720234 -0.080200  33.739714      529        3
# 4673     S1F0        0 -1.540918 -0.145660  -0.042339        0        8
# 4685     S1F0        0  1.133592 -0.080200  -0.042339        0        4
# 4686     S1F0        0 -1.563074 -0.060160  -0.042339        0        5
# ...       ...      ...       ...       ...        ...      ...      ...
# 124489   Z1F0        0 -1.475741 -0.145660  -0.042339        0       10
# 124490   Z1F0        0  0.716129 -0.129629   0.102660        4       11
# 124491   Z1F0        0 -1.465526  0.661244  -0.042339        0       11
# 124492   Z1F0        0  1.489116 -0.145660  -0.042339        0       12
# 124493   Z1F0        0 -1.486220 -0.145660  -0.042339        0       10
#
#          metric6  metric7  metric9 month weekday  failure_before
# 3051   -0.498611        0        1     1       5               0
# 3516    0.663122        0    10137     1       6               0
# 4673   -0.063393        0        0     1       0               0
# 4685    0.682726        0        1     1       0               0
# 4686    0.630570        0        0     1       0               0
# ...          ...      ...      ...   ...     ...             ...
# 124489  0.800857        8        0    11       0               0
# 124490  0.600867        0       13    11       0               0
# 124491  0.769347        0        0    11       0               0
# 124492  0.851301        0        0    11       0               0
# 124493  0.779111        0        0    11       0               0
#
# [1169 rows x 13 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1169 entries, 3051 to 124493
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   device          1169 non-null   object
#  1   failure         1169 non-null   int64
#  2   metric1         1169 non-null   int64
#  3   metric2         1169 non-null   int64
#  4   metric3         1169 non-null   int64
#  5   metric4         1169 non-null   int64
#  6   metric5         1169 non-null   int64
#  7   metric6         1169 non-null   int64
#  8   metric7         1169 non-null   int64
#  9   metric9         1169 non-null   int64
#  10  month           1169 non-null   object
#  11  weekday         1169 non-null   object
#  12  failure_before  1169 non-null   int64
# dtypes: int64(10), object(3)
# memory usage: 127.9+ KB
